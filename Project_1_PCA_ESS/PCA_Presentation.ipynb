# %% [raw]
#     <script>
#   jQuery(document).ready(function($) {
#
#   $(window).load(function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader"></div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# <h1><center> PCA: European Social Survey
#
# <center>
#     Justine Huynh
#
# <center> 2021/09/11

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import altair

# Images
from IPython.display import Image

# %% [markdown]
# Pre-Processing And Cleaning
#
# - Before: 49519 rows, 572 columns, 40.6 MB
# - After: 49519 rows, 2312 columns, 526 MB
# - OneHotEncoding, standardizing
# - No apparent y-variable (but that's okay!)
# - Some parameters: wage, country, region, trust level, politics interest
#
# PCA Implementation
#
# - `n_components` = 4
# - `whiten` = False: for uncorrelated outputs with unit component-wise variances

# %%
Image(filename = "percentVariation.png", height = 500, width = 500)

# %% [markdown]
# Components Explain Variance
# - 1st component: 64% variation
# - 2nd component: 24% variation
# - 3rd component: 6% variation
#
# Sufficient: 2 principal components

# %%
Image(filename = "importantLoadings.png", height = 700, width = 600)

# %% [markdown]
# - 1st component: Workers
# - 2nd Component: Unfair Work Conditions (Expected Fair Pay Vs. Actual Pay)
# - 3rd Component: Net Vs. Gross Pay

# %% [markdown]
# What Does This Mean For Policy Work?
#
# - Out of many variables, a few can explain data well

# %% [markdown]
#  jupyter nbconvert PCA_Presentation.ipynb --to slides --no-prompt --TagRemovePreprocessor.remove_input_tags={\\"to_remove\\"} --post serve --SlidesExporter.reveal_theme=simple
#
#  Note: don't forget the backslash to escape the quotation marks!

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Created with Jupyter, delivered by Fastly, rendered by Rackspace.
# </footer>
